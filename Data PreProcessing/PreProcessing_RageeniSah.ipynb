# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Load data into the environment
df = pd.read_csv('C:/Users/ragesah.ORADEV/Documents/R/PreProcessing/HeightWeight.csv')
df.head(5)
# Out:
#    sn  weight  height
# 0   1   65.78  112.99
# 1   2   71.52  136.49
# 2   3   69.40  153.03
# 3   4   68.22  142.34
# 4   5   67.79  144.30

# %%
df.shape
# Out:
# (200, 3)

# %%
# Check if any missing - NA values in the dataset

ifTrue = pd.isnull(df)
# Out:
#         sn  weight  height
# 0    False   False   False
# 1    False   False   False
# 2    False   False   False
# 3    False   False   False
# 4    False   False   False
# 5    False   False   False
# 6    False   False   False
# 7    False   False   False
# 8    False   False   False
# 9    False   False   False
# 10   False   False   False
# 11   False   False   False
# 12   False   False   False
# 13   False   False   False
# 14   False   False   False
# 15   False   False   False
# 16   False   False   False
# 17   False   False   False
# 18   False   False   False
# 19   False   False   False
# 20   False   False   False
# 21   False   False   False
# 22   False   False   False
# 23   False   False   False
# 24   False   False   False
# 25   False   False   False
# 26   False   False   False
# 27   False   False   False
# 28   False   False   False
# 29   False   False   False
# ..     ...     ...     ...
# 170  False   False   False
# 171  False   False   False
# ...

# %%
plt.scatter(df.height,df.weight, marker='*', c=['red','blue'])
plt.xlabel('Weight in Kg')
plt.ylabel('Height in cm')
plt.autoscale()
plt.show()

# %%
plt.subplot(2,2,1)
plt.boxplot(df.height, showbox=True, meanline=True)
plt.subplot(2,2,2)
plt.boxplot(df.weight,showbox=True, meanline=True)
plt.show()

# %%
# Perform scaling to being features into same scale range
from sklearn.preprocessing import StandardScaler
Scale = StandardScaler()
Scale.fit(df[['height','weight']])
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
plt.subplot(2,2,1)
plt.boxplot(df.height, showbox=True, meanline=True)
plt.subplot(2,2,2)
plt.boxplot(df.weight,showbox=True, meanline=True)
plt.show()
